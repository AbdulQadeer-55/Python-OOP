# %% [markdown]
# <center><h1> Object Oriented Programming - Python </h1> </center>

# %% [markdown]
# <h2> What is OOP </h2>

# %% [markdown]
# <ul>
#     <li>Procedural Programming</li>
#     <li>Object Oriented Programming</li>
# </ul>
#
# <h3> Procedural Programming </h3>
# It is a code as sequence of steps <br>
# Great for data analysis
#
# <h3> Object Oriented Programming </h3>
# <ul>
#     <li> Code as interactions of objects </li>
#     <li> Great for building frameworks and tools </li>
#     <li> Maintable and reuseable code </li>
# </ul>
#
#
# <h3> Objects as Data Structure </h3>
# <ul>
#     <li>Object = State +  Behaviour
# </li>
# </ul>
#
# **Encapsulation is where both state and behavior bind together in a single unit.**
#
#
# * Classes as blueprints
# * Objects are physical model class
#
# <p>In python everything is object like int, str and any other data type all are objects.</p>

# %% [markdown]
# ![image.png](attachment:87c07ca2-ca21-417c-9c8c-90ae09e95237.png)

# %% [markdown]
# ![image.png](attachment:a61ec838-0eab-4b42-a3cc-d0bb303ba28d.png)

# %% [markdown]
# ![image.png](attachment:ea700cef-d479-4830-b9f4-817e916cd57e.png)
# ![image.png](attachment:77480fd1-409b-42e4-916e-5a7dfd13601f.png)

# %%
class Customer:
    def identify(self, name):
        print("My name is ", name)

c1 = Customer()
c1.identify("laura")
# Out:
# My name is  laura
